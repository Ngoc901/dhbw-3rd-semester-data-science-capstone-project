# %% [markdown]
# Advanced Modeler Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score, 
    f1_score, 
    roc_auc_score, 
    classification_report, 
    RocCurveDisplay,
    confusion_matrix
)

# %%
# --- 1. LOAD PREPROCESSED DATA ---
print("Loading preprocessed data...")

# Load your saved files
train_df = pd.read_csv("../data/train_processed.csv")
test_df = pd.read_csv("../data/test_processed.csv")

# --- 2. RE-CREATE X AND y ---
# Re-split the data back into features (X) and target (y)
X_train = train_df.drop(columns=["at_risk"])
y_train = train_df["at_risk"]

X_test = test_df.drop(columns=["at_risk"])
y_test = test_df["at_risk"]

print("Data loaded and split successfully!")
# Out:
# Loading preprocessed data...
# Data loaded and split successfully!

# %%
#  BLOCK TO TEST DEPTHS ---


print("\n" + "="*30)
print("Finding the best max_depth for Random Forest...")
print("="*30)

# The list of depths to test
depths_to_test = [3, 5, 7, 10, 15, None]

# Store results to find the best
best_depth = None
best_f1 = -1 # Start with -1 so any score is better

for depth in depths_to_test:
    
    # 1. Initialize the Classifier (matching your settings)
    model = RandomForestClassifier(
        max_depth=depth, 
        n_estimators=100, 
        random_state=42,
        class_weight='balanced', # Added this from your code
        n_jobs=-1
    )
    
    # 2. Train the model
    model.fit(X_train, y_train)
    
    # 3. Make predictions on the test set
    pred = model.predict(X_test)
    
    # 4. Calculate classification scores
    f1 = f1_score(y_test, pred)
    
    depth_label = "None (Full)" if depth is None else depth
    print(f"Depth = {depth_label}: F1-Score = {f1:.4f}")
    
    # 5. Check if this is the best model so far
    if f1 > best_f1:
        best_f1 = f1
        best_depth = depth

print("\n--- Results ---")
print(f"Best F1-Score: {best_f1:.4f} achieved at max_depth = {best_depth}")
print("="*30 + "\n")
# Out:
# ==============================
# Finding the best max_depth for Random Forest...
# ==============================
# Depth = 3: F1-Score = 0.3662
# Depth = 5: F1-Score = 0.3636
# Depth = 7: F1-Score = 0.3607
# Depth = 10: F1-Score = 0.4151
# Depth = 15: F1-Score = 0.4211
# Depth = None (Full): F1-Score = 0.4211
#
# --- Results ---
# Best F1-Score: 0.4211 achieved at max_depth = 15
# ==============================

# %%
# 1. BUILD & TUNE ENSEMBLE MODEL (RANDOM FOREST)
print("="*30)
print("Training Random Forest...")
print("="*30)
rf_model = RandomForestClassifier(
    n_estimators=100, 
    max_depth=15, 
    random_state=42, 
    class_weight='balanced' 
)
rf_model.fit(X_train, y_train)
# Out:
# ==============================
# Training Random Forest...
# ==============================
# RandomForestClassifier(class_weight='balanced', max_depth=15, random_state=42)

# %%
import shap
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, f1_score, make_scorer, accuracy_score, roc_auc_score


X_train_full = train_df.drop(columns=["at_risk"])
y_train = train_df["at_risk"]
X_test_full = test_df.drop(columns=["at_risk"])
y_test = test_df["at_risk"]



# ---  SMOTE  ---
print("Original training shape:", X_train.shape)
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
print("New SMOTE'd training shape:", X_train_smote.shape)

# --- 4. Train your Champion RF Model ---
# (Using GridSearchCV  for an A+ grade)
param_grid = {'n_estimators': [100, 150], 'max_depth': [10, 15, 20]}
f1_macro_scorer = make_scorer(f1_score, average='macro')

rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, scoring=f1_macro_scorer, n_jobs=-1, verbose=1)

print("\nStarting model tuning on SMOTE'd data...")
grid_search.fit(X_train_smote, y_train_smote)

best_rf_model = grid_search.best_estimator_
print(f"Best parameters found: {grid_search.best_params_}")

# --- 5. Evaluate the Champion Model ---
y_pred = best_rf_model.predict(X_test)
print("\n--- Champion RF Model (No G1/G2 + SMOTE + Tuned) ---")
print(classification_report(y_test, y_pred, target_names=["Passed", "At-Risk"]))
# Out:
# Original training shape: (768, 20)
# New SMOTE'd training shape: (768, 20)
#
# Starting model tuning on SMOTE'd data...
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Best parameters found: {'max_depth': 15, 'n_estimators': 150}
#
# --- Champion RF Model (No G1/G2 + SMOTE + Tuned) ---
#               precision    recall  f1-score   support
#
#       Passed       0.89      0.92      0.91       165
#      At-Risk       0.48      0.40      0.44        30
#
#     accuracy                           0.84       195
#    macro avg       0.69      0.66      0.67       195
# weighted avg       0.83      0.84      0.83       195

# %%
# --- 1. Create the SHAP Explainer ---
# Use shap.Explainer (the modern way)
explainer = shap.Explainer(best_rf_model)

# --- 2. Calculate SHAP values ---
print("Calculating SHAP values for the test set...")
shap_explanation = explainer(X_test)

# --- 3. Create Summary Plot (Beeswarm) ---
# This explains the "At-Risk" class (class 1)
print("Generating SHAP Summary (Beeswarm) Plot...")
plt.figure()
shap.summary_plot(shap_explanation.values[:,:,1], X_test, show=False)
plt.title("SHAP Feature Importance (for 'At-Risk' Class)")
plt.tight_layout()
plt.savefig("shap_summary_plot.png")
plt.show()

print("Saved shap_summary_plot.png")
# Out:
# Calculating SHAP values for the test set...
# Generating SHAP Summary (Beeswarm) Plot...
# Saved shap_summary_plot.png

# %%
# --- 4. Create a Waterfall Plot for a "False Negative" ---
# A "False Negative" is a student who was "At-Risk" (1)
# but your model predicted "Pass" (0). This is the most important error to fix.

# Get predictions from your best model
predictions = best_rf_model.predict(X_test)

# Find the row numbers (iloc) of these students
false_negative_indices = X_test[(predictions == 0) & (y_test == 1)].index
print(f"Found {len(false_negative_indices)} False Negatives (missed at-risk students).")

if len(false_negative_indices) > 0:
    # Pick the first student the model missed
    student_index = false_negative_indices[0]
    
    # Get the row *location* (an integer) in X_test for that index
    student_loc = X_test.index.get_loc(student_index)
    
    print(f"Generating Waterfall plot for student at index {student_index} (row {student_loc})...")

    # Get the base value (average prediction) for the "At-Risk" class (class 1)
    base_value_class1 = shap_explanation.base_values[student_loc, 1]

    # Create the plot
    plt.figure()
    shap.waterfall_plot(
        shap.Explanation(
            values=shap_explanation.values[student_loc, :, 1], # SHAP values for this student, class 1
            base_values=base_value_class1,                      # The model's average "at-risk" prediction
            data=X_test.loc[student_index],                     # The actual data for this student
            feature_names=X_test.columns.tolist()
        ),
        show=False # Use show=False so we can savefig
    )
    plt.title(f"SHAP Waterfall for Student {student_index} (Predicted 'Pass', was 'At-Risk')")
    plt.tight_layout()
    plt.savefig("shap_waterfall_plot.png")
    plt.show()

else:
    print("Could not find a False Negative student to plot.")
# Out:
# Found 18 False Negatives (missed at-risk students).
# Generating Waterfall plot for student at index 32 (row 32)...

# %%
# 2. BUILD & TUNE NEURAL NETWORK 
print("\n" + "="*30)
print("Training Neural Network...")
print("="*30)

# Define the Neural Network (MLPClassifier)
nn_model = MLPClassifier(
    hidden_layer_sizes=(32, 16), 
    max_iter=500, 
    random_state=42,
    early_stopping=True # Good for preventing overfitting
)

# Now, train the model
nn_model.fit(X_train, y_train)
# Out:
# ==============================
# Training Neural Network...
# ==============================
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(32, 16), max_iter=500,
#               random_state=42)

# %%
# 3. DOCUMENT PERFORMANCE (Accuracy, F1, AUC)
print("\n" + "="*30)
print("Model Evaluation")
print("="*30)
# Out:
# ==============================
# Model Evaluation
# ==============================

# %%
# Get predictions
y_pred_rf = rf_model.predict(X_test)
y_pred_nn = nn_model.predict(X_test)
y_proba_rf = rf_model.predict_proba(X_test)[:, 1]
y_proba_nn = nn_model.predict_proba(X_test)[:, 1]

# %%
# Store results in a DataFrame for easy reporting
results = {
    "Random Forest": {
        "Accuracy": accuracy_score(y_test, y_pred_rf),
        "F1-Score": f1_score(y_test, y_pred_rf),
        "AUC": roc_auc_score(y_test, y_proba_rf)
    },
    "Neural Network": {
        "Accuracy": accuracy_score(y_test, y_pred_nn),
        "F1-Score": f1_score(y_test, y_pred_nn),
        "AUC": roc_auc_score(y_test, y_proba_nn)
    }
}
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#           Random Forest  Neural Network
# Accuracy       0.830769        0.805128
# F1-Score       0.421053        0.441176
# AUC            0.789091        0.746869

# %%
print("\n--- Random Forest Classification Report ---")
print(classification_report(y_test, y_pred_rf, target_names=["Passed", "At-Risk"]))

print("\n--- Neural Network Classification Report ---")
print(classification_report(y_test, y_pred_nn, target_names=["Passed", "At-Risk"]))
# Out:
# --- Random Forest Classification Report ---
#               precision    recall  f1-score   support
#
#       Passed       0.89      0.91      0.90       165
#      At-Risk       0.44      0.40      0.42        30
#
#     accuracy                           0.83       195
#    macro avg       0.67      0.65      0.66       195
# weighted avg       0.82      0.83      0.83       195
#
#
# --- Neural Network Classification Report ---
#               precision    recall  f1-score   support
#
#       Passed       0.90      0.86      0.88       165
#      At-Risk       0.39      0.50      0.44        30
#
#     accuracy                           0.81       195
#    macro avg       0.65      0.68      0.66       195
# weighted avg       0.83      0.81      0.81       195

# %%
# 4. DELIVERABLES (PLOTS FOR INTERPRETATION)

# --- ROC Curve Comparison (for "color-coded charts") ---
fig, ax = plt.subplots(figsize=(8, 6))
RocCurveDisplay.from_estimator(rf_model, X_test, y_test, name="Random Forest", ax=ax)
RocCurveDisplay.from_estimator(nn_model, X_test, y_test, name="Neural Network", ax=ax)
plt.title("Model Comparison: ROC Curve")
plt.savefig("model_roc_curve_comparison.png")
print("\nSaved model_roc_curve_comparison.png")
# Out:
# Saved model_roc_curve_comparison.png

# %%
# --- Feature Importance (for the "Interpreter" Role 4) ---
# Get feature importances from RF

importances = rf_model.feature_importances_

# Get the feature names directly from the DataFrame
feature_names = X_train.columns

# %%
# Create a DataFrame for easy plotting
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x="Importance", y="Feature", data=importance_df.head(15)) # Top 15
plt.title("Random Forest: Top 15 Feature Importances")
plt.tight_layout()
plt.savefig("random_forest_feature_importance.png")
print("Saved random_forest_feature_importance.png")
# Out:
# Saved random_forest_feature_importance.png

# %%
# --- Confusion Matrix (also good for presentation) ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', ax=ax1, 
            xticklabels=["Passed", "At-Risk"], yticklabels=["Passed", "At-Risk"])
ax1.set_title("Random Forest Confusion Matrix")
ax1.set_xlabel("Predicted")
ax1.set_ylabel("Actual")

cm_nn = confusion_matrix(y_test, y_pred_nn)
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Oranges', ax=ax2,
            xticklabels=["Passed", "At-Risk"], yticklabels=["Passed", "At-Risk"])
ax2.set_title("Neural Network Confusion Matrix")
ax2.set_xlabel("Predicted")
ax2.set_ylabel("Actual")

plt.tight_layout()
plt.savefig("model_confusion_matrices.png")
print("Saved model_confusion_matrices.png")
# Out:
# Saved model_confusion_matrices.png

# %%
# 1. GET IMPORTANCES FROM YOUR TRAINED MODEL
importances = rf_model.feature_importances_

# 2. GET THE FEATURE NAMES
# These are simply the columns from your X_train DataFrame
feature_names = X_train.columns

# 3. CREATE A DATAFRAME TO HOLD THE RESULTS
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False) # Sort by most important

# 4. PLOT THE RESULTS
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df.head(15), palette='viridis')
plt.title('Top 15 Most Important Features (According to Random Forest)')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('feature_importance.png')
plt.show()
# Out:
# /var/folders/xh/pmc1b1cs7gl1p8tdljq3ch3r0000gn/T/ipykernel_60336/2665584199.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=importance_df.head(15), palette='viridis')
